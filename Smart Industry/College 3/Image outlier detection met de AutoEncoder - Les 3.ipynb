# %%
# Run deze commands als je het nog niet hebt gedaan
# !pip install opencv-python
# !pip install pillow
# !pip install tensorflow

# %% [markdown]
# # Stap 1: Data voorbereiden:
# 1. Zorg dat je een dataset hebt van ruim meer dan 1000 afbeeldingen
# 2. Splits de data in 3 datasets:
#
#     a) x_train: ongeveer 80% van de gehele dataset
#
#     b) x_test: ongeveer 20% van de gehele dataset
#
#     c) x_val: ongeveer 5 afbeeldingen die geen anomally zijn (uit je dataset) + een aantal anomallies
# <b> Belangrijk </b>, zorg er voor data je de data _random_ split
#
# 3. Zet de afbeeldingen om naar 28 x 28
# 4. Maak de afbeeldingen zwart wit
# 5. Maak van elke dataset een numpy object met de shape (aantal_afbeeldingen, 28, 28)
#
# <b> Tip: </b> Kijk even of het is goedgegaan door door je datasets heen te bladeren en afbeeldingen met de "imshow" functie van matplotlib
#
# 6. Pixels hebben normaal een waarde tussen 0 en 255, het model werkt alleen met waarden tussen 0 en 1

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# os.chdir("Subsample_image_data")
os.chdir("image_data")

# os.chdir("Subsample_image_data__MACOSX")
# os.chdir("image_data__MACOSX")
os.listdir()

# image_name = '00001_3_F.png'
# image_name

# image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
# # image.shape
# image = Image.fromarray(image)
# image


# # resize de image
# image = np.array((image.resize((28,28), Image.LANCZOS)))
# image.shape
# Out:
# ['.DS_Store',
#  '00101_1_L.png',
#  '00101_1_L.txt',
#  '00101_2_F.png',
#  '00101_2_F.txt',
#  '00101_3_F.png',
#  '00101_3_F.txt',
#  '00102_1_F.png',
#  '00102_1_F.txt',
#  '00102_1_R.png',
#  '00102_1_R.txt',
#  '00102_2_F.png',
#  '00102_2_F.txt',
#  '00103_1_F.png',
#  '00103_1_F.txt',
#  '00103_1_L.png',
#  '00103_1_L.txt',
#  '00103_2_F.png',
#  '00103_2_F.txt',
#  '00104_1_F.png',
#  '00104_1_F.txt',
#  '00104_1_R.png',
#  '00104_1_R.txt',
#  '00104_2_F.png',
#  '00104_2_F.txt',
#  '00105_1_F.png',
#  '00105_1_F.txt',
#  '00105_1_R.png',
#  '00105_1_R.txt',
#  '00105_2_F.png',
#  '00105_2_F.txt',
#  '00106_1_F.png',
#  '00106_1_F.txt',
#  '00106_1_R.png',
#  '00106_1_R.txt',
#  '00106_2_F.png',
#  '00106_2_F.txt',
#  '00107_1_F.png',
#  '00107_1_F.txt',
#  '00107_1_R.png',
#  '00107_1_R.txt',
#  '00107_2_F.png',
#  '00107_2_F.txt',
#  '00108_1_F.png',
#  '00108_1_F.txt',
#  '00108_1_R.png',
#  '00108_1_R.txt',
#  '00108_2_F.png',
#  '00108_2_F.txt',
#  '00109_1_F.png',
#  '00109_1_F.txt',
#  '00109_2_F.png',
#  '00109_2_F.txt',
#  '00109_2_R.png',
#  '00109_2_R.txt',
#  '00110_1_F.png',
#  '00110_1_F.txt',
#  '00110_1_L.png',
#  '00110_1_L.txt',
#  '00110_2_F.png',
#  '00324_1_F.txt',
#  '00324_1_R.png',
#  '00324_1_R.txt',
#  '00325_1_F.png',
#  '00325_1_F.txt',
#  '00325_1_R.png',
#  '00325_1_R.txt',
#  '00326_1_F.png',
#  '00326_1_F.txt',
#  '00326_1_R.png',
#  '00326_1_R.txt',
#  '00327_1_F.png',
#  '00327_1_F.txt',
#  '00327_1_R.png',
#  '00327_1_R.txt',
#  '00328_1_F.png',
#  '00328_1_F.txt',
#  '00328_1_R.png',
#  '00328_1_R.txt',
#  '00329_1_F.png',
#  '00329_1_F.txt',
#  '00329_1_R.png',
#  '00329_1_R.txt',
#  '00330_1_F.png',
#  '00330_1_F.txt',
#  '00330_1_R.png',
#  '00330_1_R.txt',
#  '00331_1_F.png',
#  '00331_1_F.txt',
#  '00331_1_L.png',
#  '00331_1_L.txt',
#  '00332_1_F.png',
#  '00332_1_F.txt',
#  '00332_1_R.png',
#  '00332_1_R.txt',
#  '00333_1_F.png',
#  '00333_1_F.txt',
#  '00333_1_R.png',
#  '00333_1_R.txt',
#  '00334_1_F.png',
#  '00334_1_F.txt',
#  '00334_1_R.png',
#  '00334_1_R.txt',
#  '00335_1_F.png',
#  '00335_1_F.txt',
#  '00335_1_L.png',
#  '00335_1_L.txt',
#  '00336_1_F.png',
#  '00336_1_F.txt',
#  '00336_1_R.png',
#  '00336_1_R.txt',
#  '00337_1_F.png',
#  '00337_1_F.txt',
#  '00337_1_R.png',
#  '00337_1_R.txt',
#  ...]

# %%
# images in een list zetten
images = []
for image_name in os.listdir():
    if '.png' in image_name:
        image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
        image = Image.fromarray(image)
        image = np.array((image.resize((28,28), Image.LANCZOS)))
        images.append(image)

random.shuffle(images)
images = np.stack(images)

x_val = images[1200:1201] / 255
# x_predict = new_model.predict(x_val)
images.size
# Out:
# 898464

# %%
random.shuffle(images)
# er een numpy array van maken in plaats van list
images = np.stack(images)
images.shape


x_train, x_test = train_test_split(images, test_size=0.2, random_state=42)
# Delen door 255 om de waardes tussen 0 en 1 te krijgen
x_train = x_train / 255
x_test = x_test / 255
plt.imshow(images[8], cmap='gray')

# %%
def read_img(name):
    image = cv2.imread(name, cv2.IMREAD_GRAYSCALE)
    image = Image.fromarray(image)
    image = image.resize((28, 28), Image.LANCZOS)
    image = np.array(image).astype('float32') / 255.0
    return image

# %% [markdown]
# # Stap 2: Het trainen van de Autoencoder
# Hieronder krijgen jullie de code van het model (de autoencoder), hij is opgesschreven als functie. In de documentatie van de functie staat wat de inputs en outputs zijn.

# %%
def train_autoencoder(x_train, x_test, latent_dim, num_epochs):
    """
    :param x_train: this should be (around) 80% of your train dataset !!important, use a random split
    :param x_test: this should be (around) 20 % of your train dataset !!important, use a random split
    :param latent_dim: This is the space the images will be reduced to, to start: use the value 164, play with it later
    :param num_epochs: The number of training rounds
    :return: [0] : the trained autoencoder model
             [1] : the training data loss per epoch
             [2] : the test data loss per epoch
    """
    import tensorflow as tf
    from tensorflow.keras import layers, losses
    from tensorflow.keras.models import Model

    class Autoencoder(Model):
        def __init__(self, latent_dim):
            super(Autoencoder, self).__init__()
            self.latent_dim = latent_dim
            self.encoder = tf.keras.Sequential([
                layers.Flatten(),
                layers.Dense(latent_dim, activation='relu'),
            ])
            self.decoder = tf.keras.Sequential([
                layers.Dense(784, activation='sigmoid'),
                layers.Reshape((28, 28))
            ])

        def call(self, x):
            encoded = self.encoder(x)
            decoded = self.decoder(encoded)
            return decoded

    autoencoder = Autoencoder(latent_dim)

    autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

    history = autoencoder.fit(x_train, x_train,
                    epochs=num_epochs,
                    shuffle=True,
                    validation_data=(x_test, x_test))

    return autoencoder, history.history['loss'], history.history['val_loss']

# %% [markdown]
# ## 2.1 Trainen
# Train het model met de functie hierboven, kies een lage waarde voor de epochs

# %%
model, loss_train, loss_test = train_autoencoder(x_train, x_test, 164, 5)
# Out:
# Epoch 1/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0645 - val_loss: 0.0393
# Epoch 2/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0334
# Epoch 3/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0333 - val_loss: 0.0305
# Epoch 4/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0292 - val_loss: 0.0266
# Epoch 5/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0270 - val_loss: 0.0241

# %% [markdown]
# ## 2.2 Analyseer de loss functie:
# Plot de loss functie en bepaal of je het model lang genoeg getrained hebt

# %%
plt.plot(loss_train, label = "Loss Train")
plt.plot(loss_test, label = "Loss Test")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Train & Test")
plt.show()

# %%
encoded_imgs = model.encoder(x_test).numpy()
decoded_imgs = model.decoder(encoded_imgs).numpy()

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
  # display original
  ax = plt.subplot(2, n, i + 1)
  plt.imshow(x_test[i])
  plt.title("original")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  # display reconstruction
  ax = plt.subplot(2, n, i + 1 + n)
  plt.imshow(decoded_imgs[i])
  plt.title("reconstructed")
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # Stap 3: Predictions
# Gebruik de predict method van het model en stop hier je x_val dataset in.
# Plot de originele en gereconstrueerde afbeeldingen en vergelijk ze, zie je verschil met de outliers?

# %%
x_val = images[250:255].astype('float32') / 255.0

out1 = read_img("01489_1_F.png")
out2 = read_img("01519_1_F.png")
out3 = read_img("01550_1_R.png")

new_images = np.array([out1, out2, out3])
x_val = np.concatenate((x_val, new_images), axis=0)

x_pred = model.predict(x_val)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
size = x_val.shape[0]
plt.figure(figsize=(20, 8))
for i in range(size):
        # Original
        plt.subplot(2, size, i + 1)
        plt.imshow(x_val[i], cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        plt.subplot(2, size, i + 1 + size)
        plt.imshow(x_pred[i], cmap='gray')
        plt.title("Reconstructed")
        plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Stap 4: Outlier detection
# ## 4.1 Quanitificeer de verschillen
# Vergelijk de verschillen in de afbeeldingen met verschillende performance metrics zoals MSE, RMSE, MAPE,
# gebruik hiervoor de module <b> sklearn.metrics
#
# Kies eerst MSE om te kijken of er een significant verschill is met outliers en niet-outliers

# %%
plt.figure(figsize=(20, 8))
for i in range(size):
        # Calculate MSE
        mse = mean_squared_error(x_val[i].flatten(), x_pred[i].flatten())

        # Original
        plt.subplot(2, size, i + 1)
        plt.imshow(x_val[i], cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        plt.subplot(2, size, i + 1 + size)
        plt.imshow(x_pred[i], cmap='gray')
        plt.title(f"Reconstructed\nMSE: {mse:.4f}")
        plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.2 Tunen
# Kan je alle outliers eruit halen op basis van de metrics? Gefeliciteerd
# Mocht dit niet het geval zijn, dan kan dit aan de "latent_dim" liggen, de ruimte naar waar de afbeelding wordt samengeknepen in het model, speel met deze parameter en kijk of het de verschillen tussen de outliers en niet-outliers kan verbeteren.

# %% [markdown]
# ## 4.3 Threshold
# Als de vorige stappen goed werken wordt het tijd om automatisch aan te geven wat de outliers zijn.
# Kies een threshold voor de door jouw gekozen performance metric.

# %%
reconstructed = model.predict(images)
mse_scores = [mean_squared_error(images[i].flatten() / 255, reconstructed[i].flatten() / 255)
              for i in range(images.shape[0])]

threshold = np.mean(mse_scores) + np.std(mse_scores)
threshold
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0.6094218187451164

# %%
outliers = []
inliers = []
for i in range(images.shape[0]):
    original = images[i] / 255
    pred = reconstructed[i] / 255
    mse_val = mean_squared_error(original.flatten(), pred.flatten())
    # print(mse_val)
    if mse_val > threshold:
        outliers.append(images[i])
    else :
        inliers.append(images[i])

# %%
outliers = np.stack(outliers)
inliers = np.stack(inliers)

# %%
x_val = np.concatenate((inliers[5:10], outliers[0:3])) / 255
x_pred = model.predict(x_val) / 255
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# # Opdracht voor volgende week
# Maak een algoritme dat automatisch verteld of een afbeelding een anomally is op basis van jouw model.
#
# Deel daarnaast mogelijke interessante bevindingen.
#
# Iedereen mag even kort voor de groep presenteren

# %%
plt.figure(figsize=(20, 8))
size = x_val.shape[0]
for i in range(size):
        # Calculate MSE
        mse = mean_squared_error(x_val[i].flatten(), x_pred[i].flatten())

        # Original
        plt.subplot(2, size, i + 1)
        plt.imshow(x_val[i], cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        plt.subplot(2, size, i + 1 + size)
        plt.imshow(x_pred[i], cmap='gray')
        if mse > threshold:
                plt.title(f"Reconstructed\nMSE: {mse:.4f}\nOutlier")
        else:
                plt.title(f"Reconstructed\nMSE: {mse:.4f}")
        plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def custom_autoencoder(x_train, x_test, latent_dim, num_epochs):
    """
    :param x_train: this should be (around) 80% of your train dataset !!important, use a random split
    :param x_test: this should be (around) 20 % of your train dataset !!important, use a random split
    :param latent_dim: This is the space the images will be reduced to, to start: use the value 164, play with it later
    :param num_epochs: The number of training rounds
    :return: [0] : the trained autoencoder model
             [1] : the training data loss per epoch
             [2] : the test data loss per epoch
    """
    import tensorflow as tf
    from tensorflow.keras import layers, losses
    from tensorflow.keras.models import Model

    class Autoencoder(Model):
        def __init__(self, latent_dim):
            super(Autoencoder, self).__init__()
            self.latent_dim = latent_dim
            self.encoder = tf.keras.Sequential([
                layers.Flatten(input_shape=(28, 28)),
                layers.Dense(32, activation="relu"),
                layers.Dense(16, activation="relu"),
                layers.Dense(8, activation="relu"),
                layers.Dense(latent_dim, activation="relu")
            ])

            self.decoder = tf.keras.Sequential([
                layers.Dense(8, activation="relu"),
                layers.Dense(16, activation="relu"),
                layers.Dense(32, activation="relu"),
                layers.Dense(784, activation="sigmoid"),
                layers.Reshape((28, 28))
            ])

        def call(self, x):
            encoded = self.encoder(x)
            decoded = self.decoder(encoded)
            return decoded

    # Your model and training
    autoencoder = Autoencoder(latent_dim)

    autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

    history = autoencoder.fit(x_train, x_train,
                            epochs=num_epochs,
                            shuffle=True,
                            validation_data=(x_test, x_test))

    return autoencoder, history.history['loss'], history.history['val_loss']

# %%
custom_model, train_loss, test_loss = custom_autoencoder(x_train, x_test, 164, 150)
# Out:
# Epoch 1/150
# c:\Users\chaos\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0824 - val_loss: 0.0471
# Epoch 2/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463 - val_loss: 0.0416
# Epoch 3/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0429 - val_loss: 0.0405
# Epoch 4/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0416 - val_loss: 0.0393
# Epoch 5/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0417 - val_loss: 0.0388
# Epoch 6/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0408 - val_loss: 0.0385
# Epoch 7/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0395 - val_loss: 0.0379
# Epoch 8/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0398 - val_loss: 0.0376
# Epoch 9/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0391 - val_loss: 0.0369
# Epoch 10/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0378 - val_loss: 0.0374
# Epoch 11/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0363 - val_loss: 0.0325
# Epoch 12/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - val_loss: 0.0299
# Epoch 13/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0301 - val_loss: 0.0295
# Epoch 14/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.0286
# Epoch 15/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0289 - val_loss: 0.0282
# Epoch 16/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0284 - val_loss: 0.0279
# Epoch 17/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0285 - val_loss: 0.0277
# Epoch 18/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0283 - val_loss: 0.0276
# Epoch 19/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0287 - val_loss: 0.0275
# Epoch 20/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0280 - val_loss: 0.0271
# Epoch 21/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0270 - val_loss: 0.0261
# Epoch 22/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0265 - val_loss: 0.0245
# Epoch 23/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - val_loss: 0.0238
# Epoch 24/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241 - val_loss: 0.0236
# Epoch 25/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0238 - val_loss: 0.0234
# Epoch 26/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0235 - val_loss: 0.0230
# Epoch 27/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0233 - val_loss: 0.0230
# Epoch 28/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0234 - val_loss: 0.0229
# Epoch 29/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 30/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0231 - val_loss: 0.0228
# Epoch 31/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0233 - val_loss: 0.0227
# Epoch 32/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0233 - val_loss: 0.0227
# Epoch 33/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - val_loss: 0.0226
# Epoch 34/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228 - val_loss: 0.0226
# Epoch 35/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - val_loss: 0.0226
# Epoch 36/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - val_loss: 0.0227
# Epoch 37/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.0225
# Epoch 38/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229 - val_loss: 0.0224
# Epoch 39/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228 - val_loss: 0.0224
# Epoch 40/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - val_loss: 0.0224
# Epoch 41/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 42/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0229 - val_loss: 0.0222
# Epoch 43/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0222 - val_loss: 0.0223
# Epoch 44/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - val_loss: 0.0223
# Epoch 45/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228 - val_loss: 0.0221
# Epoch 46/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0227 - val_loss: 0.0220
# Epoch 47/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - val_loss: 0.0223
# Epoch 48/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0223 - val_loss: 0.0219
# Epoch 49/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - val_loss: 0.0216
# Epoch 50/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0219 - val_loss: 0.0214
# Epoch 51/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 52/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 53/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0220 - val_loss: 0.0210
# Epoch 54/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - val_loss: 0.0209
# Epoch 55/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - val_loss: 0.0206
# Epoch 56/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0215 - val_loss: 0.0207
# Epoch 57/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - val_loss: 0.0205
# Epoch 58/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - val_loss: 0.0204
# Epoch 59/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - val_loss: 0.0203
# Epoch 60/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0209 - val_loss: 0.0202
# Epoch 61/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 62/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - val_loss: 0.0203
# Epoch 63/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 64/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205 - val_loss: 0.0200
# Epoch 65/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - val_loss: 0.0201
# Epoch 66/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - val_loss: 0.0200
# Epoch 67/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - val_loss: 0.0200
# Epoch 68/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - val_loss: 0.0199
# Epoch 69/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0207 - val_loss: 0.0199
# Epoch 70/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - val_loss: 0.0199
# Epoch 71/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - val_loss: 0.0198
# Epoch 72/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - val_loss: 0.0198
# Epoch 73/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - val_loss: 0.0197
# Epoch 74/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - val_loss: 0.0197
# Epoch 75/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - val_loss: 0.0196
# Epoch 76/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0197
# Epoch 77/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0196
# Epoch 78/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 79/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191 - val_loss: 0.0196
# Epoch 80/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - val_loss: 0.0196
# Epoch 81/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0199 - val_loss: 0.0196
# Epoch 82/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - val_loss: 0.0196
# Epoch 83/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0195
# Epoch 84/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198 - val_loss: 0.0194
# Epoch 85/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - val_loss: 0.0193
# Epoch 86/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0190 - val_loss: 0.0193
# Epoch 87/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - val_loss: 0.0193
# Epoch 88/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195 - val_loss: 0.0193
# Epoch 89/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0192
# Epoch 90/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195 - val_loss: 0.0193
# Epoch 91/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 92/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - val_loss: 0.0192
# Epoch 93/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - val_loss: 0.0192
# Epoch 94/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - val_loss: 0.0194
# Epoch 95/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - val_loss: 0.0192
# Epoch 96/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - val_loss: 0.0194
# Epoch 97/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191 - val_loss: 0.0192
# Epoch 98/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191 - val_loss: 0.0191
# Epoch 99/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0192
# Epoch 100/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0190
# Epoch 101/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0191
# Epoch 102/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - val_loss: 0.0190
# Epoch 103/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - val_loss: 0.0191
# Epoch 104/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - val_loss: 0.0190
# Epoch 105/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 106/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0190
# Epoch 107/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - val_loss: 0.0189
# Epoch 108/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0190
# Epoch 109/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0189
# Epoch 110/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - val_loss: 0.0190
# Epoch 111/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0188
# Epoch 112/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0188
# Epoch 113/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0189
# Epoch 114/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 115/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0190
# Epoch 116/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 117/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - val_loss: 0.0188
# Epoch 118/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - val_loss: 0.0190
# Epoch 119/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0188
# Epoch 120/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0187
# Epoch 121/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0188
# Epoch 122/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 123/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0187
# Epoch 124/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0189
# Epoch 125/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0186
# Epoch 126/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - val_loss: 0.0187
# Epoch 127/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 128/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - val_loss: 0.0187
# Epoch 129/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 130/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0186
# Epoch 131/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - val_loss: 0.0188
# Epoch 132/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 133/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0185
# Epoch 134/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - val_loss: 0.0187
# Epoch 135/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 136/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0186
# Epoch 137/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 138/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0186
# Epoch 139/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 140/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - val_loss: 0.0184
# Epoch 141/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0185
# Epoch 142/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 143/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - val_loss: 0.0185
# Epoch 144/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - val_loss: 0.0184
# Epoch 145/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183 - val_loss: 0.0185
# Epoch 146/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - val_loss: 0.0184
# Epoch 147/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0185
# Epoch 148/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0185
# Epoch 149/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 150/150
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - val_loss: 0.0184

# %%
reconstructed = custom_model.predict(images)
mse_scores = [mean_squared_error(images[i].flatten() / 255, reconstructed[i].flatten() / 255)
              for i in range(images.shape[0])]

threshold = np.mean(mse_scores) + np.std(mse_scores)
threshold
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.6088822211908916

# %%
x_val = np.concatenate((inliers[5:10], outliers[3:6])) / 255
x_pred = custom_model.predict(x_val) / 255
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
plt.figure(figsize=(20, 8))
size = x_val.shape[0]
for i in range(size):
        # Calculate MSE
        mse = mean_squared_error(x_val[i].flatten(), x_pred[i].flatten())

        # Original
        plt.subplot(2, size, i + 1)
        plt.imshow(x_val[i], cmap='gray')
        plt.title("Original")
        plt.axis('off')

        # Reconstructed
        plt.subplot(2, size, i + 1 + size)
        plt.imshow(x_pred[i], cmap='gray')
        if mse > threshold:
                plt.title(f"Reconstructed\nMSE: {mse:.4f}\nOutlier")
        else:
                plt.title(f"Reconstructed\nMSE: {mse:.4f}")
        plt.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.plot(train_loss, label = "Loss Train")
plt.plot(test_loss, label = "Loss Test")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss Train & Test")
plt.show()
